# %%
# %reset -f

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_json('../input/dataset.json', lines=True)

# %%
df
# Out:
#                                                reviewText  overall
# 0       If you've read other max brand westerns, you k...        5
# 1                            Love Max, always a fun twist        5
# 2                           As usual for him, a good book        5
# 3                                              great book        5
# 4       ALMOST BEEN TOO LONG SINCE I READ IT. GOOD REA...        4
# ...                                                   ...      ...
# 879753  (7 year old's review)\n\nThey took a long time...        5
# 879754  So much fun! Very cute and well done. Pirates ...        5
# 879755  If you haven't noticed I love Kia Meches writi...        5
# 879756  I liked Secret. Sky,King,Parrish. I didn't lik...        5
# 879757  Both books were pretty good. I waited until re...        5
#
# [879758 rows x 2 columns]

# %%
corpus = []
for review in df['reviewText']:
    res = re.sub('[^a-zA-Z]', ' ', review) #Replace every non (^) letter(a-zA-Z) character by a space
    res = res.lower()
    res = res.split()
    lemmatizer = WordNetLemmatizer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove("not")
    res = [lemmatizer.lemmatize(word) for word in res if not word in set(all_stopwords)] # Apply stemming to every words except the stopwords from the english language
    res = ' '.join(res)
    corpus.append(res)

# %%
corpus
# Out:
# ['read max brand western know expect not treat let strap six gun gotta ride',
#  'love max always fun twist',
#  'usual good book',
#  'great book',
#  'almost long since read good read would not finished',
#  'enjoyed book read writer read book read good story line',
#  'good read western fan great price',
#  'hoping find one book form story look like good get far series',
#  'typical l amour western not one best enjoyable nevertheless l amour always good read good excapeism',
#  'prejudiced toward anything louis lamour writes easily one best writer th century',
#  'year reading western none better louis l amour book like rest correct place include foul language sex',
#  'tragic love story leave series question love love much love not exactly reciprocal',
#  'true story amazing thing got away long nd good person',
#  'fun adventure read',
#  'amazing tale man got away not believe managed get away thing',
#  'great book read two flight could not stop reading even better movie highly recommend adding collection',
#  'love story chewie e book exception great character introduction wonderful story line',
#  'love anything chewbacca family bonus kind nice see problem son',
#  'seen movie based book loved surprised loved book well sheer audacity near unbelievable love anyway',
#  'exciting book hardly imagine happened young man say really intelligent resourceful pleased red book enjoy',
#  'book incredible good reading leave amazed fast thinker quick user people yet bank learned much updating system must read',
#  'great book good movie astounding trick trade recommend book relax enjoy',
#  'great',
#  'liked movie loved book really give idea brutal foreign prison',
#  'ebook readable',
#  'real adventure story true',
#  'well written fast paced seen movie still enjoyed book story quite entertaining quick read',
#  'almost good movie fun read believe saved favorite writing not exciting escapade happened',
#  'great learning experience shocked french prison system inhumane surprise young frank swindling day glad life worked',
#  'thrilling exciting agatha christie novel reading first two chapter could not put book',
#  'entertaining enjoyed profanity always felt want get away something openly flair boldness',
#  'unfortunately see movie movie half good book certain definitely successful venture truly enjoyable read',
#  'interesting great read loved would better author left conquest really pertinent story',
#  'best true crime story ever would recommend anyone looking remarkable story well worth purchase',
#  'believe frank got away crime unbelievable well believable story unfolds great exciting read',
#  'star good space adventure tale held interest',
#  'great space opera',
#  'one interesting book read time well worth time spent',
#  'almost dumped novel mark ky aunt mom machination bored hell became reasonable space oater hammer slammer not waste time',
#  'good story love vatta watching go trial tribulation well handed',
#  'like one potato chip eat one read entire series',
#  'liked story',
#  'love series love book kylara great character know book feel firefly pretty much fave sci fi series',
#  'love book strong woman main perspective rest series really drawing well wait take trip together get lost another world',
#  'character vivid plot thickens story line flow seem fall m moon story',
#  'even third time worth lot action intense situation elizabeth moon never let want military adventure',
#  'loved whole series strong heroine true value smart',
#  'always moon delivers well written page turner strong female protagonist highly recommend',
#  'enjoyed book think good others',
#  'ky vatta engaging character intellect common sense adventurous spirit action made keep reading late night',
#  'moon writes well excellent characterization complex world explored loving detail well worth space kindle one best series',
#  'like like fun sci fi yarn move along nicely looking forward reading series',
#  'fun fast engaging space opera lover like strong female lead highly recommend book go',
#  'really enjoyed moon vatta war find relaxing space opera really dig character thing would normally consider mundane moon make fascinating',
#  'one well deserving award story interesting writing far better plot cloudstreet rider',
#  'like style part',
#  'pigeon tony grandson frank lawyer judy well written elibrary book',
#  'boy hold interest twist turn lombard street ending not see coming totally engaging',
#  'book well written trouble putting lot action got learn bennie life',
#  'like lisa scottoline book enjoyed one much would could work exciting office well done always',
#  'wish known series started book good gotta go back',
#  'thought book okay storyline interesting many unanswered question concerning separation sister father etc',
#  'like lisa scottoline never read time never disappointed book one great lawyer murderer corrupt cop everything',
#  'great story old way eye eye interesting watch judy grow confidence attorney like series',
#  'love series',
#  'great book love rosato asspciate series',
#  'great book become fan since read first ever lisa scoreline book fast easy reading make hard put love wait see outcome storyline',
#  'book draggy enjoyed several others not keep interest not finish reading',
#  'started reading m scottoline book middle series decided go back beginning series glad great series',
#  'book superb full suspense favorite character pigeon tony make feel range emotion along spanning sixty year',
#  'good',
#  'loved',
#  'believe book read kindle paper back way fine start',
#  'lot wonderfully relatable nugget gleaned book',
#  'book inspiration crisis faith resulted feeling like not hearing god',
#  'reading book woman bible study church book awesome highly recommend anyone inspiring closer relationship christ',
#  'really nice',
#  'great',
#  'good spiritual read learned would recommend book one struggling issue',
#  'joyce meyer book came expected timely manner',
#  'good reading',
#  'like good product',
#  'horrible idea gave killed million not billion people',
#  'quick delivery great since needed class thanks great condition',
#  'good old read',
#  'good read faulty ideology real life book cause many suffer disguise social justice equality instead caused suffering dismay mass',
#  'not fan censorship book inspired murder people enslaved nation not sold anywhere',
#  'wanted read work mad man',
#  'read book yet sure could possibly four',
#  'described',
#  'must history buff well written contextualizing introduction downside ilustrations seem zoom properly iphone',
#  'good version',
#  'important understand communist thinking goal',
#  'learning history learning good bad ugly encourage read book see flawed thinking',
#  'good',
#  'hmmm not everyone going see thing thing way life deal harmony',
#  'garbage author delusional nutjob locked away',
#  'good reference book want know engels marx truly not portion spun lame street medium',
#  'better thought',
#  'engels hand small capitalist drag chain clinton crew modern natural new target worker world',
#  'like newton physic whole longer considered valid contains brilliant insight',
#  'good',
#  'looking',
#  'great',
#  'interesting read year ago h really dated',
#  'decent read would recommend history lover easily relatable modern society sense people want change want revolutionary action',
#  'order critique something necessary know one talking book good purpose',
#  'great read thanks',
#  'open mind idea',
#  'get around someday think enjoy remained focused',
#  'great deal price',
#  'really like book',
#  'asdf',
#  'good read',
#  'go communism',
#  'find old copy since moved simply research comparison today',
#  'great',
#  'got reference not ideology adhere would commend',
#  'frankly know hoopla found practical old fashioned express opinion well well written',
#  'wanted know combat',
#  'usefull',
#  'great purchase',
#  'great read made realize conservative idea wtf mean say commie also marx really believed good human being whole poor naive bastard',
#  'excellent',
#  'excellent read take bit get really provides good insight',
#  'like fine',
#  'classic',
#  'necessary reading want comprehend mind set tactic behind communist threat not long take investment',
#  'c',
#  'classic',
#  'absolutely essential',
#  'good read understand world around',
#  'must read',
#  'kidding right free curious bought',
#  'big read best tackled general introduction economic theory surprise far popular work not working class',
#  'glad read sm loss understand inspired new political system',
#  'ordered school',
#  'tried read multiple time content presented dry way',
#  'good',
#  'interesting read item arrived good condition',
#  'bunch word take enough space get recorded yep take make nonexistent comment',
#  'scary mentality interesting none le',
#  'good academic reviewing',
#  'everyone copy read least year would allow better understanding government not',
#  'lot good story always wanted read story movie lot different',
#  'intresting',
#  'people read book thing remind happening u',
#  'ok not really easy read understand bit disappointed',
#  'love sci fi one great much better remake go wrong buying movie',
#  'history reference',
#  'read gumnami baba',
#  'great insight well worth time educate oneself motivation political propaganda',
#  'great book',
#  'great book',
#  'must read know one set bad guy mind',
#  'good know',
#  'good book',
#  'good source obtaining understanding thought precept communist dogma',
#  'badly wrirren manifesto',
#  'badly written manifesto',
#  'much learn one super read really recommend sort thing find reading',
#  'rather not say anything awful book diabolical opinion not worth time comment',
#  'found quite scary wanting understand happening washington dc pray overturned',
#  'really good read book really brings home stuff see going right open eye',
#  'struggle read class struggle simplistic view solving world problem blaming man',
#  'book filled theory based idea utopian life eartg idea perfect society great attempt failed failing even china moving towards capitalism',
#  'everyone read book love freedom personal liberty know vice enemy may freedom reign forever',
#  'damn good writer must read action read book write review least word plenty book buy repeated word count',
#  'choose rating product excellent dislike nothing would recommend product anyone interested',
#  'good experience would defintely order vendor',
#  'classic book free else people want beggar chooser always said',
#  'purchased curiosity real interest touched idea manifesto philosophy class wanted get idea writer ideology whole',
#  'great source term paper liked easy read understand great college source',
#  'least understand basis communism proletariat bourgeoise place workforce switch communism time soon great work nonetheless',
#  'book give reader clear view communism supposed not became',
#  'book classic must read value freedom karl marx set tone standard communism socialism little brother',
#  'really surprising see amazon com sale rank book u never see anyone buying reading book inside china',
#  'book simple read yet complicated read wish change dog eat dog world humane peaceful one',
#  'believer believe god ask happen die',
#  'decent look phenomenon near death experience always appreciate learning survivor experience',
#  'seller good job book description wear marking book arrived without delay excellent sellor',
#  'book uplifting one would recommend good spiritual book great family loved one',
#  'purchased gift told one best near death book written plan purchasing one',
#  'great book keep guessing entire book',
#  'velvet night silver morning mean sex love pleasure family friendship hope memory plain life find answer story',
#  'boring slow read plot far fetched plod along slow pace leading character obnoxious waste time better book',
#  'know m johanson manages keep enticing story going strong great full story mesmerizing',
#  'love iris johannes writing book entertaining flow follow great next one',
#  'great historical story really get feel soldier civil war might went main character surprising enjoy book',
#  'ordered book friend recommendation visited carnton surrounding area enjoyed seeing picture book',
#  'around boring book always finish boo konce start reading finished woah take work go back forth way much overall plain boring',
#  'always lookout author not read yet glad discovered allison brennan reading rest trilogy',
#  'written mystery interesting developed character great fast moving story line would recommend series anyone enjoys action mystery enjoy reading',
#  'awesome book full suspense action',
#  'checked book library book absolutely amazing really loved enjoyed reading book would highly recommend book',
#  'great audio book edge seat entire book',
#  'great read',
#  'another great suspenseful novel great read',
#  'suspensful',
#  'kill third book predator trilogy romantic suspense series written author allison brennan',
#  'killing fear first suspense book prison break trilogy written allison brennan yet another excellent story author',
#  'sudden death excellent exciting first romantic suspense book f b trilogy series written author allison brennan',
#  'see evil second book evil trilogy written author allison brennan great story overuse word gasped',
#  'action packed',
#  'good read',
#  'read lucy kincaid story loved not read back story wonderful mystery giving information lucy brother conner julia great read',
#  'great book',
#  'another winner allison brennan one pretty intense learn bit jack kincaid ride next',
#  'finishing trilogy book get learn olivia st martin book tie everything together love book read separately still make sense',
#  'loved waiting next series',
#  'book exciting book would recommend book others would read ebooks',
#  'good read lot twist turn book keep guessing every book read allison brennan phenomenal',
#  'great read',
#  'great read',
#  'great read',
#  'great read',
#  'good read',
#  'really like series book page turner surprise end',
#  'really enjoyed book referenced character already familiar allison brennan fatal secret really cool also nice mix romance suspense',
#  'always winner',
#  'love allison brennan book exception',
#  'love allison brennan must read book really helped complete saga',
#  'love author',
#  'read m brennan book terrific storyteller great combo suspense romance plan read book',
#  'complaint alison brennan put book go bed awesome writer',
#  'read three series one better previous one wait start next series',
#  'second predator series good first not want put book excellent read thanks',
#  'fast paced entertaining reading definitely recommend enjoyable afternoon hope rest trilogy well written',
#  'always allison brennan delivered suspense book excellent read absolutely recommend suspense thriller lover',
#  'always allison brennan delivered suspenseful edge seat thriller book good took day half finish',
#  'great book easy read cannot think additional word say amazon minimal requirement really stink really stink',
#  'love allison brennan book read far strongly recommend book others well',
#  'great book lot twist turn keep reading finished one night hard put',
#  'read numerous allison brennan book far favorite book kept guessing murderer started book put',
#  'news quality rating easily star price brings three star rating priced high digital news source',
#  'gteat',
#  'along w ny time atlantic daily app essential reading informed american',
#  'great',
#  'easy navigate even small kindle appreciate much',
#  'good newspaper kindle version ok still prefer paper version though',
#  'downloaded read sitting ocean something cool reading journal beach like article',
#  'got husband got formed revewed yet ask couple week',
#  'using kindle read newspaper difficult book much easier flow page page without lot searching',
#  'kindle edition wsj priced great wonderful kindle get monthly edition find useful love',
#  'excellent adaptation jane austen persuasion book would recommend jane austen fan entertaining well developed character',
#  'worried book would cheesy surprised good plot great world building',
#  'story really good different vampire book good way really enjoyed story character',
#  'surprisingly fun',
#  'omg love series different new wait read next one',
#  'good',
#  'enjoyed book first read came still fun book even reading several time recommend book series',
#  'fantastic going love one try read order go lyndsay website get listing',
#  'saw popular gave shot cup tea',
#  'typical book thread reference novel',
#  'even finish develop rapor character',
#  'loved light humorous lightly sexy',
#  'lynsay book enjoyable',
#  'amazing book',
#  'rather short really good job introducing u argenau clan really enjoyed',
#  'really like series read st book slow area overall liked',
#  'romantic comedy guilty pleasure read people want distracted day day seriousness',
#  'far one dumbest vampire book ever read writing lack maturity bad',
#  'good go bed good book read enjoyed experience reading book written well',
#  'ok',
#  'well written easy read leaf hooked wanting',
#  'liked story line disappointed action not giving though book',
#  'sand written new take vampire mythology good start series look forward rest series',
#  'really good read liked explanation vampire came love story supernatural politics enough tension',
#  'vampire faint sight blood original sand',
#  'one favorite author love argeneau vampire book',
#  'loved story much beautiful lissianna hunk dr gregory hewitt love hardback book',
#  'second book read loving story twist turn keep guessing often',
#  'love series could not put book lynsay sand book awesome love',
#  'hooked series right lynsay way word book light funny story',
#  'good book one favorite author love series keep em coming',
#  'book fantastic wait rest story love family friend',
#  'great book',
#  'great funny read',
#  'fun entertaining book looking forward rest series',
#  'really enjoyed reading story wonderful interesting love character series wait next one',
#  'argeneau vampire load fun love good vampire story one fit bill another author wish found year ago fantasy wonderful thing matter age enjoy',
#  'hopefully ive read sweet sexy full story continue buy come',
#  'great read wonderful story great buy well worth time money get read try like',
#  'not come anything new say book good others',
#  'really enjoy lynsay sand book one not disappoint great paranormal read mood one',
#  'love lynsay sand book read many keep name straight star opinion',
#  'go wrong argeneau book plot character make want continue read',
#  'guick bite currently reading far like starting get really good wait see end',
#  'not huge fan vampire romance genre love series think sand unique take vampirism make enjoyable read',
#  'loved book much buy one daughter friend read series',
#  'thought book excellent definitely worth reading glad got one look forward next book series',
#  'book go think better others book great quick read stop worth',
#  'like campy vampire romance love series book another family memeber',
#  'love argeneau series quick read never fail hold attention never miss one one great',
#  'thanks writing book charming story romance mystery funny bit action family dynamic',
#  'start great funny series read book wanted find looking forward book want argeneau',
#  'push finish book hoping would get better never save money',
#  'omg ob famly love book wonderful story beyond happy book go get think enjoy well',
#  'argeneau series great series get started first get fall love character',
#  'leave lynsay keep steamy series argeneau family hope never end',
#  'could not get book story line contrived character idiotic never finished think going back author',
#  'love gray lady',
#  'complaint cannot merge subscription werth existing access subscription',
#  'reasonable news source bargain price',
#  'biased',
#  'factual coverage detail',
#  'along w wsj atlantic daily app essential reading informed american',
#  'political correct',
#  'along washington post nyt best paper amazon land sunday edition five buck paper copy cent best deal kindle kindle land',
#  'structure order artices make boring tead dallas pretty good newspaper los angeles time usually great read',
#  'conservative curious flagship liberal newspaper treated news took advantage free trial nyt great newspaper cup tea long term',
#  'good laugh',
#  'well done',
#  'le advertised le print paper',
#  'favorite national newspaper',
#  'ny time great read little expensive opinion e reader version buy often enjoy reading news paper',
#  'reliable lot good reading kindle edition veru comfortable travelling paper already recommended long time',
#  'downloaded read vacation good paper covered everything interested reading',
#  'month incompleat e newspaper care ny time called rip book',
#  'paper ok disappointed comic otherwise would subscribe full time',
#  'premier newspaper new england sent automatically beloved kindle sleep trudging snow find wet soggy glop dead tree nice',
#  'love reporter wish new home delivery carrier understood delivery instruction aim front door enjoy get',
#  'boston globe great paper miss vacation however g connection kindle pick daily even overseas great price presently cent per copy deal',
#  'still one best paper country much behind scene information around community many city area state',
#  'got look ad rental course kindle edition none even scanning news almost got sick liberal news',
#  'newspaper looked boston globe jam packed seen new england paper kindle',
#  'love reading year load fast fire hd issue subscription call amazon sorted wonderful story content live without',
#  'excellent reading complete newspaper enjoy much reading',
#  'enjoy reading newspaper real fact checked news',
#  'wonderful way read post',
#  'cover lot territory still getting used far broad coverage thorough reporting',
#  'good coverage ad free',
#  'good read not real paper story nice easy pull comic missing key section sport business still make need buy paper',
#  'reporting good higher priced good newspaper tend get newspaper basically news',
#  'one time cursory look one interested going washington dished regular press good read',
#  'cool forgot request rate came make mine unreliable rating doubt change rotation planet enough measure',
#  'washington post lot information needed american receiving kindle time nice format really surprised thank dee',
#  'ereader newspaper love price right would not pay anymore',
#  'good',
#  'nice read every city problem besides one one crime drug not alone well put together paper',
#  'app slow usually update properly getting picture etc difficult online version work significantly easier better',
#  'son life dublin time keep abreast current event ireland',
#  'wonderful dose old sod recommend front back page reading bad day week',
#  'enjoy weekend magazine saturday addition especially story irish life human interest',
#  'something would normally look tracking hurricane atlantic headed uk thought would find spectacular landing ireland',
#  'got couple time enjoyed writing style prose covered nice variety subject come think not sure not purchased often got go',
#  'go new kindle',
#  'not bulk selection cost financial paper maybe little le conservative show anyway',
#  'looking chart little snippet headline top story nothing like paper get satisfaction',
#  'love insight boba',
#  'gotten time read one yet intend read soon though look like good book',
#  'boba fett sort get screwed turn around start screwing yuzahn vong cool',
#  'ti good short story hoping not big fan yuzan vong war series good anyway would better',
#  'hate e book loathe fact time available read good story',
#  'great book informative would recommend',
#  'finally lifestyle make sense',
#  'informative',
#  'really hoping get complete list glycemic index load food',
#  'product arrived good condition merchant kind send product timely fashion',
#  'easy follow diet plan stay life hungry lose weight',
#  'heartbreaking story amazing turn justice sisterhood lose julia jack nicki make find woman need justice serve',
#  'enjoyed reading book exciting intriguing read book one half day suzanne wrosch',
#  'although reading series order not necessary strong woman character good story goal justice sisterhood continues adventure',
#  'great storyline pace fairly fast move well sister overcome tragedy persevere fulfill mission loved',
#  'jury fern michael released sisterhood novel lot action plot violence fan fern michael like',
#  'book good job describing people place event take place book',
#  'loved',
#  'love sisterhood series',
#  'another good read fern michael',
#  'good',
#  'love sisterhood book wait read next one',
#  'enjoyed sisterhood book one exception think know sister michael throw sort twist',
#  'enjoyed reading',
#  'really enjoyed series well written keep interest always wondering woman next graphic violence book',
#  'like fern michael sisterhood book go one right next',
#  'awesome read',
#  'fern michael know write bad book several author count great book one best',
#  'really enjoying series long next book stay continue buying book good writing great character fun stuff',
#  'read day hooked sad julia died glad lady got even jack took care guy attacked friend good book',
#  'whole series worth reading',
#  'love series',
#  'set book called sisterhood terrific going book day really enjoy character plot woman seek justice incredible next',
#  'far brought book plan reading love love series thanks fern michael writing series',
#  'always every book sisterhood series excellent',
#  'like',
#  'love series',
#  'sisterhood book great',
#  'read',
#  'fun easy read',
#  'another great sisterhood book series',
#  'excellent read',
#  'really like subject matter fern michael writes really tuned way woman feel many time wanted right wrong done',
#  'liked sisterhood series many adventure',
#  'remember buying book sorry',
#  'arrived quickly described thanks',
#  'great read',
#  'received',
#  'always refreshing hear truth',
#  'love hard time waiting see punish next guilty party fern michael genius writer',
#  'good read',
#  'loved story child',
#  'love sisterhood story disappoint fence skip one miss much story lne',
#  'love author book wait read story always waiting recent book',
#  'love fern michael book revenge get even good read enjoy one let everyone know sisterhood wish one lol',
#  'guess book okay could not get never finished reading listening cannot offer good opinion',
#  'love',
#  'thanks great product never disappointed order thru amazon',
#  'another wonderful story sisterhood getting revenge not quite detail michael sisterhood book fast read pleasure reading nikki revenge',
#  'jury excellent book enjoy fern michael book especially sisterhood series godmother series',
#  'one lady art class recommend series loved would recommend anyone',
#  'one lady art class recommend series loved would recommend anyone',
#  'loved',
#  'amazing book must read classic',
#  'love love love book',
#  'nikki jack get back together think read whole series start next one see series go recommend something missing',
#  'great story strong woman men love good combination sisterhood get justice woman wronged wish men nowadays like',
#  'sisterhood series one best read ever honestly could not put book got caught charecters like spending time friend',
#  'good book keep wanting series would recommend friend series exciting brings surprise',
#  '',
#  'fern get high mark another good story make revenge unique would recommend story friend like well written story',
#  'loved series like book stop one probably read month get',
#  'awesome',
#  'ok',
#  'excellent book series seem get enough start new one soon finish one still reading',
#  'great book',
#  'continue thru sisterhood series remain bit disturbed lady justify thing unsavory character im still dealing gratuitous swearing',
#  'good tale',
#  'book free download amazon kindle store happy',
#  'grimm never get old',
#  'ok',
#  'good read',
#  'good',
#  'say beat good story full',
#  'twist turn continue sister revenge sisterhood series retaliate ever cross woman',
#  'awesome',
#  'remember story kid',
#  'complain free',
#  'love fern michael book sisterhood series great really loved kentucky vega series better though',
#  'always liked grimm',
#  'thanks',
#  'right series seems going hope sweet revenge better',
#  'dark spooky collection nightmarish fantasy',
#  'several old friend revisited reading well know fun read',
#  'thank',
#  'online book purchase enjoy able read book ipad iphone device instantly nice feature',
#  'never chance read guess might ok oh',
#  'really great purchase good price even leave home convenient',
#  'classic classic reason version wonderful version free nice perk well',
#  'classic else say edition good read fairly quickly nice see tale original format',
#  'fun story read child always asking read favorite book excellent writer jacob grimm every child someone read',
#  'fell love show thought would read story themself thease story twisted fantastic read',
#  'interesting book time back woman subservient men whim yet enjoy reading',
#  'grimm fairy tale known worldwide reason best best never read truly sheltered missing best fiction ever',
#  'got sounded good pas kindle freebie besides good classic hard pas',
#  'arrived expected fun reread fairy tale fun revisit youth would recommend anyone',
#  'fallen love grimm tale new v show lot fun read',
#  'brand use give need continue use future',
#  'not exactly remember story might different version one read',
#  'grimm fairy tale highly enjoyable story fairly entertaining price could not better free',
#  'glad new version grimm story grew reading grimm andersen lost old storybook many year ago comforting reread',
#  'ordered kindle classic kid read well enjoy reading book get expensive thank',
#  'excited read year tale came back vivid reminder youth great book',
#  'many tale aparently cosmeticly rendered disney ilk gas not read since childhood recommend',
#  'promised',
#  'funny definitely worth price free laughing not good p g wodehouse vein great reading phone waiting anything',
#  'truly hilarious book small masterpiece bizzare unusual witty good language well written absolutely great classic',
#  'must read age grate read want tell much book ill end giving away',
#  'give star read worse book book boring yadda yadda type recommend',
#  'book give u something besides growing root butt watching much tv read book',
#  'aptly named need said could give still rate would',
#  'enjoyed book great deal witty pleasant read actually laugh loud couple time thanks free classic',
#  'mary jane holmes exihibits great character developement witty intruiging slightly implausible plot beware certain character doomed ready weep demise',
#  'loved story kit still love stupid ten additional required word jelllo',
#  'newer nurse aid came across book accidentally downloaded whim hoping would provide different view ethic nursing not disappointed',
#  'daughter registered nurse start talking situation challenge work come reference think know cheating lol',
#  'great',
#  'recommend book anyone interested apocryphal legend often particular charm read like pious imaginative fable',
#  'not history reasoning behind constitution want found excellent read give place honor reference',
#  'great info wrtings debate find volume grat histroy duff kindle edition free',
#  'read got cause time free lol figured risk end get time read',
#  'writing style period stilted story interesting not flow well character not always clearly developed',
#  'good',
#  'great book',
#  'good thought provoking book hard time reading due content made emotional must read black history people',
#  'got whole bunch free book download read yet appear issue downloading',
#  'wonderful book good information recommend site friend family great job amazon thank site',
#  'great purchase',
#  'interesting look life participant great war certainly man changed war',
#  'lose war lose boat lose girl maybe kind insight mentality upper class german take thing',
#  'first not know expect started reading however interesting provides appears historical account event war',
#  'gist captured u boat commander diary tell triumph woe underwater land meet girl go liked',
#  'absolutely fell love minute started reading',
#  'top five rooting stone horse ride mountain madison horse ride two get together',
#  'love story strong grounded men know secure solid family book',
#  'really love writer never disappoints love knowing story continue blend together give charcaters like good job m jackson',
#  'finally texas newspaper kindle format way go amazon',
#  'every time picked page news felt preferential governor perry would prefer non biased paper',
#  'news beside people killing want variety defenitely not going obtain',
#  'excellent paper thing wish could change time read love able get single edition periodically kindle wonderful',
#  'easy navigate great newspaper enjoyed reading even small kindle',
#  'think charge lower since not include sunday holiday not many article writing good though enjoy reading',
#  'never made impression may try point forgetable expecting',
#  'favorite anytime overseas particularly read editorial publisher key country point view particularly commenting united state',
#  'middle road',
#  'one issue trial format not strong',
#  'love layout easy read go enough news without much editorializing thanks',
#  'fell love caribbean part based book moved love stella thanks terry',
#  'woman sexy sassy find fun entertaining story drawn author marriage',
#  'enjoyable comical story older woman going vacation fling young man well written character well portrayed',
#  'read book great really enjoyed hated ended get heather graham book',
#  'heather graham quickly become favorite author surprise every book written never see twist coming wonderfully scripted love story',
#  'difficult navagate also coould eliminate obit',
#  'got news local paper word word word word word word word word word word word word word word word word word word',
#  'flavor star added subscription definitely starting improve worth price least',
#  'not worth time',
#  'find needed like sport comic etc take space kindle caused slow think removed',
#  'much better newspaper many others much better written story new yok time not left leaning still well writtin story los angeles time',
#  'paper really good job story missing much content thing real newspaper comic key part business section sport section',
#  'not include comic really love sf chronicle kindle continue regular newspaper',
#  'like blog going affected new nyt pay wall drop',
#  'love sherlock holmes sir arthur conan doyle everything doyle wrote amazing',
#  'oldie goody forget mystery use read really enjoyed series',
#  'fun reading',
#  'say conan doyle sherlock holmes already said interested logic deduction book ultimate',
#  'say story one greatest writer english language love',
#  'say conan doyle sherlock holmes oh let not forget dr watson',
#  'sherlock fan certain sure',
#  'enjoying reading fire phone lot read read holmes work glad find one low price well worth price',
#  'adventure thrill action great detection better sherlock holmes love collection much read time far',
#  'found story teal life interesting reminds much pain world prayer miracle happen',
#  'absolutely love series wait write blossom street book even trying hand knitting love character fit life',
#  'good read nicely tying character story fun',
#  'not single book bloom street book like love every one cannot go wrong feel like part family read',
#  'read book blossom street loved every minute',
#  'love book put back track reading great story people friend like make reading fun thanks next book',
#  'really enjoy amazon daily find book deal information easily quickly definitely worth signing',
#  'ever say free really not let buy tell akre embarqmail com please write back',
#  'like article whish would open content list button cancel subscription',
#  'excellent',
#  'hope author writes another book shayes enjoyed book well written great story',
#  'third son daniel shaye series recommend reading order good hope randisi writing another family',
#  'enjoyed reading intend read book author',
#  'vaughan written great story sheep cattle open range problem come gready cow rancher not wanting sheep range series hawke great read',
#  'looking forward reading next hawke story vaughan amazing addition reading recommend author book',
#  'admit western pianist gunfighter not interest much not read author would highly recommend good read enjoy',
#  'great',
#  'good',
#  'another great adventure hawke clear easy going firm forceful way',
#  'good western',
#  'good story',
#  'good western adventure',
#  'enjoy reading western need hawke series',
#  'great book loved think better read long time buy bok',
#  'normal cattle men hate sheep men end work cattle men kill sheep sheep men good read',
#  'never really bought character gun fighter concert pianist',
#  'robert vaughn always good',
#  'enjoyable book read partial western one kept attention',
#  'good writer',
#  'go wrong hawke book missed not aware would rectify situation order amazon',
#  'exciting reading',
#  'good read western good guy win baddie lose',
#  'vaugan hawk great reading never want stop reading start',
#  'good time filler',
#  'wondering say would good not repeat always lamour fan man close given u another fine example art',
#  'good book worth reading',
#  'love entire series ready read hold interest',
#  'another good robert vaughn book read quite book past year always impressed writing look shop book',
#  'second book read series enjoyed reading book book pulled almost page one would highly recommend book',
#  'read hawke series wish hopefully mr vaughan write',
#  'war might deciding right another fast moving western vaughan hold interest first page buy one',
#  'love love love story could not put kindle read rest series week must read',
#  'enjoy erotic fiction book even finish book lewd word extremely graphic sex scene porn book',
#  'pretty good book book grab within first couple chapter get hooked nice read loaded kindle free',
#  'not found bored not interested character could not finish unusual',
#  'loved adventure devlin group series shannon stacey little excitement little sex happy ending could ask',
#  'wow st time reading author definitely buy thought suspense well done kept edge seat romance good',
#  'great romance action love story loved situation ending would recommend book anyone love romance',
#  'advid reader loved book captivating great fantasy woman read',
#  'love book book everything love book good put love book',
#  'book funny exciting character great detail great easy read keep attention',
#  'thoroughly enjoyed reading book called two sighted easy read lot fun',
#  'ainslinn kyle two well thought character enjoyed ainslinn letting go fear allowing kyle get close loved book',
#  'liked ok liked next one much better main character bland pretty sterotypical',
#  'downloaded initially onto kindle later deleted useless',
#  'excellent transaction item described fast shipping thank',
#  'good found difficult navigate',
#  'item exactly advertised',
#  'great product fast delivery',
#  'never read',
#  'good catholic version',
#  'jump verse hard navigate',
#  'hard find anything kindle order second',
#  'happy find',
#  'free kindle not chance review christmas time',
#  'retired nurse always interesting read knowledge former year interesting enlightening',
#  'many thing book find something cover anything might looking like look see',
#  'not much fun book thing really outdated really common sense know not good read',
#  'husband ordered said really thought would like',
#  'reader want lot sex short book thing looking plot characterization not satisfy',
#  'writing left bit desired seemed like written teenager trying grown not favorite caught rolling eye quite time',
#  'read quite book author easy read not explicit sex give pas ih',
#  'lori foster put one favorite series one already book paperback stored kindle plus rereading old friend nice',
#  'book easy read little sexy good story family men life bought several book',
#  'lori foster captured attention story give great detail story excellent plot',
#  'loved book series author great book read yet disappoint',
#  'book think think romance novel want hot steamy sex scene romance great dialogue relationship book cheese',
#  'love guy say enough bought book individually bundle definitely better way go mention love buckhorn brother',
#  'really enjoyed bundle nice beable read left hanging son book story love read anyone know',
#  'definitely recommend winner',
#  'christina skye book keep getting better better wish would write great action romance rolled one',
#  'big fan able read bunch author series story one time made day',
#  'story cute romantic find men unreasonable unwilling see anything woman perspective might find story irratating read',
#  'desert rouge series paperback read glad finally get ebooks',
#  'romantic story men finding mate attract modern day story interesting accomplished goal',
#  'love intire story line desert rogue paperback happy see kindle',
#  'desert rouge series paperback read glad get ebooks',
#  'romantic story men finding mate attract interesting accomplished goal',
#  'whole desert rogue series awesome men alpha male woman strong well written must read',
#  'another great set story almost fall guy make unbelievably perfect always smile silly prince falling love',
#  'loved four book',
#  'little social commentary humor always love crusie read write good thing prolific endlessly varied story',
#  'adore book always funny romantic pretty darn good story',
#  'good story four story great character great story line cruise give light reading style enjoy',
#  'always thrilled jennifer crusoe book writes great book loved always look forward new book',
#  'get enough jennifer crusie bundle great value enjoyed story intertwined wait read jennifer book',
#  'delightful reading writes story ohio make believable funny time',
#  'susan wiggs weave marvelous tale wonderful character vista time high sea mousy woman magnificent lion man true page turner',
#  'fun see connection one section wondered historical fact concerning slavery correct',
#  'kept attention way thru found accident glad sure looking forward',
#  'read school liked',
#  'super weird beautifully written',
#  'brilliant book good second reading first make good book group book even book usually read challenging fiction',
#  'care book read chapter',
#  'uniquely written story loved saw character eye different section book found totally absorbing start finish',
#  'second half much better first half',
#  'story multifaceted difficult follow time issue along historical event give insight character future behavior',
#  'oscar wao sad story sad life touched heart learned much life dominican republic horrible year trujillo',
#  'fun entertaining fairly layered book quirky character interesting culture history found really nothing outstanding deserves much recognition',
#  'got image force scientific reading',
#  'wow thought mind bending exciting hard wrap one head around worth every moment trying well done',
#  'though fascinating subject lot information head not science wiz familiar term used would love learn',
#  'explains full depth field book open mind new realm way great book',
#  'great book',
#  'read like doctoral thesis well researched not particularly easy read',
#  'fascinating reason give star felt got little confusing time actually gave much detail would great college course',
#  'great book slow read full good information never even considered reading book must read',
#  'brilliant research explanation world got stuff stuff',
#  'sure author sure conclusion seemed pointless anecdotal not worth time took read',
#  'updated decent plan found hard stick gone back weight watcher new point plan effective',
#  'good book enjoyed reading trying adopt suggestion',
#  'lost pound week using recipe book following guideline awesome recommended everyone know trying lose weight work',
#  'use book',
#  'formula easy follow',
#  'nothing new far information diet exercise medication diabetes go four area need covered book pretty limited food wee bit rest',
#  'thought provocative trying link balance method make sense think may sensitive self test great help',
#  'sport fanatic many story related knew still not good book really short suppose worth money really wanted',
#  'fun read quick dose laughter barbara way could always find way make u laugh best medicine',
#  'struggling mild depression singing blue book lift awesome hold hope anyone going rough patch made laugh lot',
#  'book funny plain relaxing glad purchased light read awesome book go others',
#  'excellent transaction item described fast shipping thank',
#  'good clear writing leader dedicated serving god',
#  'good book really enjoy dr stanley viewpoint delivered quickly excellent like new condition pleased purchase',
#  'fantastic book read read periodically must read anyone looking grow closer god holy spirit',
#  'interesting reading',
#  'loved way people took care',
#  'wondrous story growing coping pain life throw powerful relationship woman highly recommend',
#  'book one could not put kept wanting learn character fit together kept hoping lily found family',
#  'interesting little long winded',
#  'read book year ago book club picked last month still great nd time around',
#  'beautifully written real work art read kindness read book',
#  'well written smart spontaneous imagination completely believable self talk bad ray could not compassionate man n end',
#  'great story well written',
#  'wonderful story great character development really creates full picture end enough surprise keep predictable wonderful book',
#  'enjoyed book much learned lot bee not know read book',
#  'good reread section library',
#  'loved book movie brought back lot not nice history segregatuon',
#  'brilliant read year ago love remains',
#  'book deserves star one best ever read cried like lost family member time reading tremendous book',
#  'still reading',
#  'put believe read long ago new inspiring coming age',
#  'go star one not favorite well worth reading liked story woman life intertwined loved strengthened',
#  'great read',
#  'second time reading enjoyed much',
#  'loved book gald read fact read every book author written good read good value',
#  'love character way author take place heartwarming book miss pink house beautiful loving woman live',
#  'wonderful book easy read hated see end',
#  'marvelous book enjoyed much pleasant easy read best part relationship people',
#  'love story',
#  'wonderful book beautifully written',
#  'kept entertained finished not really style book',
#  'one would read loved information bee wisdom tucked away book sad sweet',
#  'comment except kidd great author',
#  'enjoyed story plot line good read',
#  'great book page turner really got involved character loved',
#  'great read heartwarming story like living south reading feel like know character',
#  'loved book told everyone get looking',
#  'read book reading second time book club noticed first time book sisterhood woman enjoyable',
#  'not expecting not good found boring shallow',
#  'wow thought bit slow going first hooked awesome book highly recommend',
#  'love descriptive way sue monk kidd writes',
#  'know read one great read',
#  'love book',
#  'wonderful book thought provoking twist expect excellent work',
#  'good story kind slow read romance buff anyway interested see movie though',
#  'intertwining world nature human contribute compassion wisdom young woman coming age enjoyable pleasantly tactile sweet',
#  'loved help saving cee cee honeycut love book set civil right era south wonderful book strength woman',
#  'beautiful complex story surviving childhood neglectful father mother simple easy read well written',
#  'may guy may chick flick book plenty angst also one hugely clever fun book read many year huge thumb',
#  'sue monk kidd research well understand bee work understand people relate wonderful read',
#  'loved kidd book beautifully written thoroughly enlightening every one read want know deep south really like book give glimpse',
#  'heartwarming really good book want end wait get hand movie watch',
#  'excellent know missed one first came enjoyed every word',
#  'seems like already reviewed way splendid reading cared people interacted good author',
#  'thought lovely story not amazing like help example cute story entertaining albeit not page turner',
#  'beautiful novel put book good funny emotional character fascinating even ray',
#  'much enjoyed individual book book word collection great price review work fun different',
# ...
#  'mystery gold st biel solved gabby colm get making baby good read',
#  'another great read m gardwood one time favorite author excitement drama intrigue everything could possibly want',
#  'awsome',
#  'another great book julie garwood want put like series character carry book book',
#  'never fails make happy reader',
#  'always loved book happy add kindle read',
#  'lovely story lord lady love julie garwood book especially one highland laird another great read author',
#  'anything julie garwood writes read one favorite time since read comment story',
#  'read book think written m garwood first contemporary romance sincerely hope writes another story wonderful',
#  '',
#  'great keep book others hoarded julie garwood exciting av',
#  'many clan name got lost awhile story dragged place however mystery humor danger love finally happy ending could ask anything',
#  'third book character secret ransom one fun watching strong character fight control relationship',
#  'julie garwood one favorite writer always lose book magical way make belie true people',
#  'another great historical julie garwood fun adventure quick witted lead character around great novel',
#  'great book good story great character pretty well researched historical storyline great book',
#  'enjoyable book read partial western one kept attention',
#  'another entertaining western another good job writer another promising good book enjoyed',
#  'loved read story hawke',
#  'read hawke series waiting next one',
#  'want get headache try read book even keep name straight',
#  'book okay could showing love everything explained maybe even anna got pregnant sex onetime',
#  'suprisingly good',
#  'great book keep track dream not reality world deal u hand',
#  'good',
#  'real meat potato get fired like make motivational book read seem like baby food read',
#  'enjoyed book much',
#  'although book usual element good western added story line europe gave expansive feel',
#  'good read',
#  'ok',
#  'robert vaughn writes well character well developed',
#  'hawke without soul go childhood friend also regiment hawke good story',
#  'exciting western',
#  'not great read',
#  'enjoyable book read partial western one kept attention',
#  'great',
#  'genre follows pretty much pattern admit like action make predictable',
#  'exciting reading',
#  'entertaining book',
#  'good western',
#  'excellent book second read author character seem real plot well thought written plan read book',
#  'first book mr vaughn loved read work',
#  'author keep interest good western good guy win',
#  'ride western country see happens good book',
#  'hawke concert piano player buy chose play solon small town also good gun need read book find thing',
#  'always great reading robert vaughan hawke',
#  'liked',
#  'enjoyed book',
#  'read couple book hawke series enjoyed robert vaughn one better author western book',
#  'go mr vaughan written another good book recommend read book enjoy western writing u',
#  'good book fast reading enjoyable',
#  'really enjoyed book especially back ground hawke smart guy',
#  'hawke ride devil action packed thriller keep edge seat end good read',
#  'hawke great character rough tough gentle smart time enjoyable read give true flavor old west could',
#  'hawk town need help criminal expertise bring change add novel bucket list',
#  'hawke man one world accomplished pianist went join war caught killed could longer play piano world stage great read',
#  'started reading robert vaughan enjoyable say least hawke quirky fun western action gunslinger continue read author',
#  'good book glad bought kept interest way thru book enjoy reading western know like reading book',
#  'like series lainey character waaay much clutz lol',
#  'ok read flow well lot seemed forced liked plot character though lainey annoying',
#  'book best memoir mental illness ever read put together grace truth without harm anyone excellent',
#  'book mandatory anyone associated schizophrenia whether professionally caretaker family member real eye opener',
#  'loved gave better understanding like schizophrenia interesting',
#  'excellent insight mind real schizophrenia patient',
#  'memoire woman schizophrenia go difficult time surprise come end functional person big surprise well written',
#  'stay one sure first getting started reading time finished elyn became one hero',
#  'great little summary historical discovery around world ten course author favorite make compelling case one',
#  'fascinating read knew interesting see chose specific event',
#  'really quick review important archaeological find history awesome book make want research done',
#  'enjoyed book found wordy instance good story line could shortened',
#  'say book boring care happened character read agent savich sherlock book enjoyed',
#  'first book read oriah loved kindle read anywhere want perfect',
#  'exbfbuy',
#  'needed poetry writing prose right thank book blessing high recommend reading reread',
#  'great series among favorite author never disappoints',
#  'read book thru year nice together read bundled set even couple never read',
#  'loved',
#  'maggie shayne one favorite author time writing impeccable loved story wait read wing night part',
#  'problem little bit story rush discriptive sex',
#  'read story past glad able read',
#  'held moment started reading right last page left wanting',
#  'powerful story one kept spellbound love way maggie shayne writes onto part',
#  'story keep reading draw keep reading love maggie story',
#  'really enjoy maggie shayne book like creativity fact story make laugh cry rage character develop',
#  'love maggie shayne one best loved series mich get part two really good several book one connects great book',
#  'maggie always writes great book book good kept finish reading go wrong getting book',
#  'wonderful book vampire lover fantasy loved vampire reader maggot shayne book one favorite',
#  'book well written thought story grab think mood time nothing related book',
#  'wing night part happy chance revisit series cannot wait',
#  'story kept attention hard put author weave tale help develop kinship character fantastical world',
#  'absolutely fantastic series sexy vamp scary bad guy well told loved hero heroine equally pick favorite want please',
#  'really enjoyed following character story vampire secret government agency conspiracy intrigue romance could want',
#  'loved th book favorite love version vampire keep going book wish last little longer though',
#  'maggie shayne intertwines people way captivates plowed story great plot action',
#  'thought read oh maggie shayne book wrong good entertaining recommend highly',
#  'loved story couple missed take another world great character awesome story love must read maggie shayne fan',
#  'lost much sleep reading story could not put kindle keep reading thank wonderful adventure',
#  'wonderful collection full length book loved every one unique vampire story',
#  'love book maggie shayne awesome story great read anyone love romance',
#  'love maggie shayne book several story come together good read recommend',
#  'paperback series keep reading reread book time rock',
#  'maggie great job hooked give spoiler must say recommend book story flowed easily kept wondering',
#  'book great read definitely read book author well written move well little romance little fun one',
#  'loved series book always like maggie shayne kept busy day keep tissue handy lot vampire adventure',
#  'love read series one great m great job character building fresh story',
#  'trashy romantic vampire novel well written caught kept attention read entire series even predictable',
#  'get book amazing read not regret purchasing not able put',
#  'wish could make required reading high school across united state',
#  'well written agree fact presented',
#  'levin great insight toward scotus reader cannot go wrong exploring book foundation work based solid research',
#  'easier read mark book good historical overview third branch government citizen read',
#  'laborious reading place',
#  'enjoyed book anything mr levin writes excellent',
#  'levin extraordinary men black readable encourage anyone interested fixing problem country face read book',
#  'extremely enlightening',
#  'mark levin tell like really father book mandatory reading jr high sr high',
#  'wow never knew missed not reading book year earlier want know started country drift constitution book',
#  'excellent review court decision u may trying persue life without feeling need monitor legal trend closely real eyeopener good read',
#  'book bad surely like still enjoyed even quick book need much said',
#  'great book',
#  'right kind alpha pretty steamy looking clean historical romance not wait read another author',
#  'really enjoyed story way start darkness bitterness slowly turn brightness love excellent read',
#  'time round believed scotte barrett tale doubled addiction viscount great backing story provides many pleasant interlude',
#  'read couple hour put loved look author',
#  'excellent read',
#  'great story emotional not mention full surprise say least put',
#  'enjoyed',
#  'captivating start finish put',
#  'love book',
#  'read began love affair brenda jackson novel',
#  'great book',
#  'great read character relatable drew story looking forward reading dex',
#  'great',
#  'great book',
#  'iove brenda jackson book character intriguing funny extremely romantic love hardly wait next book',
#  'book good miss explosive sex scene m jackson known book',
#  'lorren issue deep ugly justin right get right together',
#  'great begining great family saga story begining finding fated mate',
#  'way protected reassured amazing strong character book always love happy ending',
#  'justin learns even though loose love cancer chance may find love someone else great read',
#  'like author way telling story entetaining story suuitable young reader well adult',
#  'real soldier veteran knew fight',
#  'informative depth many surprise man marine hero',
#  'great',
#  'topic discus kid bully drug use topic find rd book series along friendship perseverance right thing patience',
#  'great series',
#  'great series',
#  'battle skandia ok twist turn not going spoil book entertaining rand woodman',
#  'good book wow scoping scrub without even using pure wow power book contains good much plot',
#  'wowing wowability seems good wowed book like moment scoping sum scrub pure wowness',
#  'enjoyable read',
#  'sped right put',
#  'great happy ending even better cliff hanger book perfect sequel previous one',
#  'liked bad guy actually sort good guy except deparneiux think book may dwelled warmweed addiction long',
#  'loved series book fast paced without lot extra fluff highly recommend',
#  'loved series book fast paced without lot extra fluff highly recommend',
#  'loved book first time read long ago loved reading today one student reminded book reading well excellent book well crafted',
#  'series awesome two son fight get read new one first',
#  'series awesome two son fight get read new one first',
#  'good',
#  'great book',
#  'love thesis book character',
#  'love character series eachonebuilds last could still read alone',
#  'great character development intrigue downright fun wholesome sad depicts old world really existed long ago',
#  'good read',
#  'great series kid love well written',
#  'easy read',
#  'setting series kinda boring sometimes not loving main character immediately made loving book series easy',
#  'good action good book',
#  'riveting knuckle white reading battle part love book may grown love read whole series',
#  'awesome',
#  'awesome',
#  'friggin care review button',
#  'friggin care review button',
#  'give star please',
#  'book good still lot stuff unexpected still think could end another book two part seem like dragging still good',
#  'another great book series made far keep going get better better',
#  'another great book book brings deeper deeper world love every minute',
#  'awesome book great seller',
#  'ending caught bit guard book amazing definitely going get next book would recommend try ranger apprentice series',
#  'good read even adult well written pretty predictable bad price probably going keep many reader away',
#  'book filled difficult choice dilemma war another great story including hint romance john flanagan keep coming',
#  'hero villain load action excitement male female reader wait see next',
#  '',
#  '',
#  'entertaining whole family good series kid starting get chapter book',
#  'entertaining whole family good series kid starting get chapter book',
#  'nothing really say except good temujai seemed fashioned mongol genghis khan',
#  'drugged evanlyn needing act story provides good need progress making impossible put',
#  'loved book much last one wait read next book sure great story',
#  'really enjoyed book great story easy read hard time putting',
#  'always need say something eating book th book already know amazing',
#  'one complaint dang book short read book day annoys',
#  'im constant reader ive read harry potter hobbit lord ring hundred one fovorites',
#  'well written interesting liked way kept storyline',
#  'good read teen',
#  'good book character develop',
#  'good book character develop',
#  'reading made wish viking total must read',
#  'one best book ever read reading series fantastic highly recommend anybody like read',
#  'another great ya book john flanagan strong character male female face many plot twist last page wait get next book',
#  'okay guess good reading book',
#  'okay guess good reading book',
#  'liked one okay liked one recommend series though',
#  'mom bought series love reading whole series loved hunger game better one one best',
#  'yet another well written installment ranger apprentice series follow another action packed adventurous portion life apprentice ranger',
#  'fast paced action adventure tight story line pleasant series book worth reading simple plot moving towards satisfying ending',
#  'good book tween boy would recommend parent buy kid',
#  'good book tween boy would recommend parent buy kid',
#  'interesting realistic series pulled right probably favorite series far wish would book little longer',
#  'another thrilling exiting superb book full suspense venture humour fantastic book nothing said',
#  'another fantastic ranger apprentice book must read fan sequel cannot missed fantasy adventure fan',
#  'another masterpiece written great author hopefully make book series',
#  'another masterpiece written great author hopefully make book series',
#  'great series put absolute favorite whole series cannot wait book ten',
#  'great series put absolute favorite whole series cannot wait book ten',
#  'exciting last time read also found skipped page book funny typo',
#  'book best series far loved action fantastic descriptive battle scene good character well defined',
#  'fantastic writing flanagan enthralled writing way competing top fantasy writer modern age',
#  'fantastic writing flanagan enthralled writing way competing top fantasy writer modern age',
#  'love series book disappoint skandian book make anything better',
#  'great series book make meet awesome character finish last book series left',
#  'good read kept interest keen level throughout enjoy good book without sex bad language recommend youth reader',
#  'series keep getting better large battle great wait read next book recommend read series',
#  'highly recommend anyone read previous entry great book good ending story keep getting better',
#  'great book except little short liked plot exciting except cussed slot think read ten plus',
#  'book good last better great middle school upper elementary reader love war story hero',
#  'got hooked series friend read one not disappoint awesome',
#  'got hooked series friend read one not disappoint awesome',
#  'year old son enjoyed every book series refreshingly absent witchcraft vampire full epic battle excitement',
#  'year old son enjoyed every book series refreshingly absent witchcraft vampire full epic battle excitement',
#  'wife reading series enjoyed book not bog',
#  'two son sharing series one another read book love lot',
#  'series awesome give every book star loved cant help fall love character',
#  'series amazing doubt love addictive story flow nicely one book next',
#  ...]

# %% [markdown]
# # TF-IDF Method

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=1000)
X = tfidf.fit_transform(corpus).toarray()
y = df["overall"].values

# %%
from sklearn.model_selection import train_test_split

X_tfidf_train, X_tfidf_test, y_tfidf_train, y_tfidf_test = train_test_split(X, y, test_size=0.33, random_state=50)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

from sklearn.metrics import accuracy_score,make_scorer, classification_report
from sklearn.model_selection import GridSearchCV
# Out:
# WARNING:tensorflow:From C:\Users\lsaid\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_tfidf_train_encoded = label_encoder.fit_transform(y_tfidf_train)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(X_tfidf_train.shape[1],), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))  # 5 classes for ratings 1 to 5
optimizer = Adam(learning_rate=0.001)
loss = SparseCategoricalCrossentropy()
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# Training the model
model.fit(X_tfidf_train, y_tfidf_train_encoded, epochs=5, batch_size=32, validation_split=0.1)

# Evaluating the model
y_pred_proba = model.predict(X_tfidf_test)
y_pred = label_encoder.inverse_transform(y_pred_proba.argmax(axis=1))

# Evaluation
accuracy = accuracy_score(y_tfidf_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Additional metrics
print(classification_report(y_tfidf_test, y_pred))
# Out:
# WARNING:tensorflow:From C:\Users\lsaid\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\lsaid\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\lsaid\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 16578/16578 [==============================] - 60s 4ms/step - loss: 0.7815 - accuracy: 0.6800 - val_loss: 0.7682 - val_accuracy: 0.6838
# Epoch 2/5
# 16578/16578 [==============================] - 57s 3ms/step - loss: 0.7564 - accuracy: 0.6894 - val_loss: 0.7588 - val_accuracy: 0.6860
# Epoch 3/5
# 16578/16578 [==============================] - 57s 3ms/step - loss: 0.7431 - accuracy: 0.6945 - val_loss: 0.7568 - val_accuracy: 0.6874
# Epoch 4/5
# 16578/16578 [==============================] - 57s 3ms/step - loss: 0.7325 - accuracy: 0.6991 - val_loss: 0.7566 - val_accuracy: 0.6879
# Epoch 5/5
# 16578/16578 [==============================] - 58s 3ms/step - loss: 0.7231 - accuracy: 0.7037 - val_loss: 0.7575 - val_accuracy: 0.6878
# 9073/9073 [==============================] - 17s 2ms/step
# Accuracy: 0.69
#               precision    recall  f1-score   support
#
#            1       0.51      0.38      0.44      7035
#            2       0.38      0.11      0.17      7952
#            3       0.46      0.37      0.41     24827
#            4       0.49      0.22      0.30     65927
#            5       0.74      0.94      0.83    184580
#
#     accuracy                           0.69    290321
#    macro avg       0.52      0.40      0.43    290321
# weighted avg       0.65      0.69      0.65    290321

# %% [markdown]
# # Single prediction

# %%
def predict_rating(text):
    corpus = []
    res = re.sub('[^a-zA-Z]', ' ', text.lower())
    res = res.split()
    lemmatizer = WordNetLemmatizer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove("not")
    res = [lemmatizer.lemmatize(word) for word in res if not word in set(all_stopwords)]
    res = ' '.join(res)
    corpus.append(res)
    X = tfidf.transform(corpus).toarray()  # Use transform, not fit_transform
    prediction_proba = model.predict(X)
    predicted_class = label_encoder.inverse_transform([prediction_proba.argmax()])[0]
    print(f'Predicted Rating: {predicted_class}')

# %%
text = "i have seen better."
predict_rating(text)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Predicted Rating: 5

# %% [markdown]
# As you can see, some sentences are not well guess. It might be because of :
# - Lack of datas on low rating
# - Use of TF-IDF that doesn't take the context of words into account

# %% [markdown]
# So the next steps should be :
#
# - Getting more data of bad rated reviews (1 to 3)
# - Learn about Contextual Word Embedding
