# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_json('../dataset/Kindle_Store_5.json', lines=True)

# %%
dataset
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 0              4      True   07 3, 2014  A2LSKD2H9U8N0J  B000FA5KK0
# 1              5      True  05 26, 2014  A2QP13XTJND1QS  B000FA5KK0
# 2              5      True  09 16, 2016   A8WQ7MAG3HFOZ  B000FA5KK0
# 3              5      True   03 3, 2016   A1E0MODSRYP7O  B000FA5KK0
# 4              5      True  09 10, 2015   AYUTCGVSM1H7T  B000FA5KK0
# ...          ...       ...          ...             ...         ...
# 2222978        3     False  07 16, 2016  A3Q6HJYRJX87Z9  B01HJENY3Y
# 2222979        5     False  07 12, 2016  A2O7HQNKCMOMUP  B01HJENY3Y
# 2222980        5     False   07 1, 2016  A38NOWP7LQI8CM  B01HJENY3Y
# 2222981        5     False   07 1, 2016  A1H9WGEEKVK0FM  B01HJENY3Y
# 2222982        5      True   07 1, 2016   AGBVBXSAJDD4H  B01HJENY3Y
#
#                                   style         reviewerName  \
# 0        {'Format:': ' Kindle Edition'}  sandra sue marsolek
# 1        {'Format:': ' Kindle Edition'}                  Tpl
# 2        {'Format:': ' Kindle Edition'}  Alverne F. Anderson
# 3        {'Format:': ' Kindle Edition'}                 Jeff
# 4        {'Format:': ' Kindle Edition'}    DEHS - EddyRapcon
# ...                                 ...                  ...
# 2222978  {'Format:': ' Kindle Edition'}                Tokea
# 2222979  {'Format:': ' Kindle Edition'}       Angela Burnett
# 2222980  {'Format:': ' Kindle Edition'}              Treka22
# 2222981  {'Format:': ' Kindle Edition'}    Adrienne Jeremiah
# 2222982  {'Format:': ' Kindle Edition'}  Shonnikkia Francois
#
#                                                 reviewText  \
# 0        pretty good story, a little exaggerated, but I...
# 1        If you've read other max brand westerns, you k...
# 2                             Love Max, always a fun twist
# 3                            As usual for him, a good book
# 4        MB is one of the original western writers and ...
# ...                                                    ...
# 2222978  Ok book but some parts just didn't add up I fe...
# 2222979  Kia I loved this book.  I am so glad that Sky ...
# 2222980  This picks up where part one left off. Secret ...
# 2222981  What a beautiful ending to such a twisted begi...
# 2222982  Honey let me tell you Ms. Kia must have been r...
#
#                                             summary  unixReviewTime vote image
# 0                                 pretty good story      1404345600  NaN   NaN
# 1                                  A very good book      1401062400  NaN   NaN
# 2                                        Five Stars      1473984000  NaN   NaN
# 3                                            a good      1456963200  NaN   NaN
# 4                                         A Western      1441843200    2   NaN
# ...                                             ...             ...  ...   ...
# 2222978                                   Cool book      1468627200  NaN   NaN
# 2222979                                  Crazy Read      1468281600  NaN   NaN
# 2222980                                    Loved it      1467331200  NaN   NaN
# 2222981                            Beautiful ending      1467331200  NaN   NaN
# 2222982  Glad Tuesday received her happy ever after      1467331200  NaN   NaN
#
# [2222983 rows x 12 columns]

# %%
dataset.iloc[0,:]
# Out:
# overall                                                           4
# verified                                                       True
# reviewTime                                               07 3, 2014
# reviewerID                                           A2LSKD2H9U8N0J
# asin                                                     B000FA5KK0
# style                                {'Format:': ' Kindle Edition'}
# reviewerName                                    sandra sue marsolek
# reviewText        pretty good story, a little exaggerated, but I...
# summary                                           pretty good story
# unixReviewTime                                           1404345600
# vote                                                            NaN
# image                                                           NaN
# Name: 0, dtype: object

# %%
dataset = dataset[dataset["reviewText"].str.len() <= 200]

# %%
dataset
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 1              5      True  05 26, 2014  A2QP13XTJND1QS  B000FA5KK0
# 2              5      True  09 16, 2016   A8WQ7MAG3HFOZ  B000FA5KK0
# 3              5      True   03 3, 2016   A1E0MODSRYP7O  B000FA5KK0
# 5              5      True  06 14, 2015   A9DXGM6YGV14D  B000FA5KK0
# 7              4      True   05 3, 2015  A12AIK6DSUF1EW  B000FA5KK0
# ...          ...       ...          ...             ...         ...
# 2222970        5     False   07 9, 2016  A1X2QS73EH0T90  B01HJCNGZ2
# 2222973        5     False  06 28, 2016  A2NLILKXV548RT  B01HJCNGZ2
# 2222975        5     False   03 8, 2017  A3RJ27BQRYHOWC  B01HJENY3Y
# 2222976        5     False  10 24, 2016  A316WPH4MMVSHD  B01HJENY3Y
# 2222977        5     False   09 7, 2016  A1XKQXXHDI4Z7D  B01HJENY3Y
#
#                                   style         reviewerName  \
# 1        {'Format:': ' Kindle Edition'}                  Tpl
# 2        {'Format:': ' Kindle Edition'}  Alverne F. Anderson
# 3        {'Format:': ' Kindle Edition'}                 Jeff
# 5        {'Format:': ' Kindle Edition'}      Linda DeWachter
# 7        {'Format:': ' Kindle Edition'}             R. DAVIS
# ...                                 ...                  ...
# 2222970  {'Format:': ' Kindle Edition'}             M. Dumas
# 2222973  {'Format:': ' Kindle Edition'}                  Don
# 2222975  {'Format:': ' Kindle Edition'}               Breona
# 2222976  {'Format:': ' Kindle Edition'}      Kindle Customer
# 2222977  {'Format:': ' Kindle Edition'}         Felicia C/O.
#
#                                                 reviewText  \
# 1        If you've read other max brand westerns, you k...
# 2                             Love Max, always a fun twist
# 3                            As usual for him, a good book
# 5                                               great book
# 7        ALMOST BEEN TOO LONG SINCE I READ IT. GOOD REA...
# ...                                                    ...
# 2222970  (7 year old's review)\n\nThey took a long time...
# 2222973  So much fun! Very cute and well done. Pirates ...
# 2222975  If you haven't noticed I love Kia Meches writi...
# 2222976  I liked Secret. Sky,King,Parrish. I didn't lik...
# 2222977  Both books were pretty good. I waited until re...
#
#                       summary  unixReviewTime vote image
# 1            A very good book      1401062400  NaN   NaN
# 2                  Five Stars      1473984000  NaN   NaN
# 3                      a good      1456963200  NaN   NaN
# 5                  Five Stars      1434240000  NaN   NaN
# 7        ANOTHER GOOD WESTERN      1430611200  NaN   NaN
# ...                       ...             ...  ...   ...
# 2222970                  Cool      1468022400  NaN   NaN
# 2222973          So much fun!      1467072000  NaN   NaN
# 2222975                     !      1488931200  NaN   NaN
# 2222976         Tonya- Review      1477267200  NaN   NaN
# 2222977   Poison Kisses 1and2      1473206400  NaN   NaN
#
# [879758 rows x 12 columns]

# %%
unused_columns = [
    "verified",
    "reviewTime",
    "reviewerID",
    "asin",
    "style",
    "reviewerName",
    "summary",
    "unixReviewTime",
    "vote",
    "image"
]
dataset.drop(columns=unused_columns, inplace=True)
# Out:
# C:\Users\lsaid\AppData\Local\Temp\ipykernel_11308\2094714112.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(columns=unused_columns, inplace=True)

# %%
dataset
# Out:
#          overall                                         reviewText
# 1              5  If you've read other max brand westerns, you k...
# 2              5                       Love Max, always a fun twist
# 3              5                      As usual for him, a good book
# 5              5                                         great book
# 7              4  ALMOST BEEN TOO LONG SINCE I READ IT. GOOD REA...
# ...          ...                                                ...
# 2222970        5  (7 year old's review)\n\nThey took a long time...
# 2222973        5  So much fun! Very cute and well done. Pirates ...
# 2222975        5  If you haven't noticed I love Kia Meches writi...
# 2222976        5  I liked Secret. Sky,King,Parrish. I didn't lik...
# 2222977        5  Both books were pretty good. I waited until re...
#
# [879758 rows x 2 columns]

# %%
dataset[dataset["overall"] == 1]
# Out:
#          overall                                         reviewText
# 236            1          I didn't like the style or any part of it
# 315            1  Horrible ideas that gave killed millions if no...
# 322            1  I am not a fan of censorship, but this book ha...
# 336            1  Garbage. Author is a delusional nutjob that sh...
# 388            1  You are kidding right?  It was free, I was cur...
# ...          ...                                                ...
# 2222738        1  well now I know every bit of black slang on th...
# 2222825        1  I'm not keeping this story.  Not my type of ro...
# 2222828        1                                           Just no.
# 2222860        1  I had to quit as this was poor science fiction...
# 2222909        1  What a waste of time, NOTHING made sense.  It ...
#
# [21196 rows x 2 columns]

# %%
dataset = dataset[[col if col != "overall" and col != "reviewText" else "overall" if col == "reviewText" else "reviewText" for col in dataset.columns]]

# %%
dataset
# Out:
#                                                 reviewText  overall
# 1        If you've read other max brand westerns, you k...        5
# 2                             Love Max, always a fun twist        5
# 3                            As usual for him, a good book        5
# 5                                               great book        5
# 7        ALMOST BEEN TOO LONG SINCE I READ IT. GOOD REA...        4
# ...                                                    ...      ...
# 2222970  (7 year old's review)\n\nThey took a long time...        5
# 2222973  So much fun! Very cute and well done. Pirates ...        5
# 2222975  If you haven't noticed I love Kia Meches writi...        5
# 2222976  I liked Secret. Sky,King,Parrish. I didn't lik...        5
# 2222977  Both books were pretty good. I waited until re...        5
#
# [879758 rows x 2 columns]

# %%
dataset.isna().sum()
# Out:
# reviewText    0
# overall       0
# dtype: int64

# %%
dataset[dataset["reviewText"].isna()]
# Out:
# Empty DataFrame
# Columns: [reviewText, overall]
# Index: []

# %%
dataset.dropna(inplace=True)

# %%
dataset[dataset["reviewText"].isna()]
# Out:
# Empty DataFrame
# Columns: [reviewText, overall]
# Index: []

# %%
from collections import Counter
sentiment_distr = Counter(dataset["overall"])
print(sentiment_distr)
# Out:
# Counter({5: 559925, 4: 199963, 3: 74779, 2: 23895, 1: 21196})

# %%
dataset.to_json('../input/dataset.json', orient='records', lines=True)
